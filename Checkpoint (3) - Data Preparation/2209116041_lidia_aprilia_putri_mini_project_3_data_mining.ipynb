# %% [markdown]
# <a href="https://colab.research.google.com/github/Lidiaaprilia/Mini-Project-Data-Mining-2024/blob/main/2209116041_lidia_aprilia_putri_mini_project_3_data_mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Analisis Tingkat Kebahagiaan Negara Dunia**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot
from google.colab import drive

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# ##**Business Objective**

# %% [markdown]
# Tujuan bisnis dari dataset ini adalah untuk menganalisis faktor-faktor apa yang memengaruhi tingkat kebahagiaan masyarakat di berbagai negara. Variabel-variabel seperti GDP per kapita, dukungan sosial, tingkat harapan hidup, kebebasan dalam bersuara atau membuat pilihan hidup, tingkat korupsi, dan tingkat kedermawanan dapat berkontribusi terhadap tingkat kebahagiaan setiap negara. Melalui dataset ini juga memungkinkan adanya perbandingan antara negara-negara untuk melihat perbedaan dalam variabel-variabel tingkat kebahagiaan.

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Situasi bisnis yang mendasari analisis ini adalah pemerintah dari suatu negara dapat menggunakan data tingkat kebahagiaan dunia untuk membentuk kebijakan publik yang lebih baik untuk meningkatkan kualitas hidup masyarakatnya. Tidak hanya dari pihak pemerintah, namun pihak dari suatu perusahaan juga dapat menggunakan data ini untuk mengembangkan produk dan layanan baru sesuai dengan tingkat kualitas hidup masyarakat.

# %% [markdown]
# ##**Data Mining Goals**

# %% [markdown]
# Tujuan dari Data Mining pada dataset ini adalah untuk membantu mengidentifikasi dan menganalisis variabel-variabel seperti GDP per kapita, dukungan sosial, tingkat harapan hidup, kebebasan, tingkat korupsi, dan tingkat kedermawanan yang berkontribusi pada tingkat kebahagiaan di berbagai negara. Data mining juga dapat membuat prediksi tentang tingkat kebahagiaan di masa depan. Selain itu, analisis data mining pada dataset ini diharapkan dapat memberikan wawasan bagi pemerintah untuk merancang kebijakan yang bertujuan meningkatkan kesejahteraan dan kebahagiaan masyarakatnya.

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Rencana proyek untuk menganalisis dataset ini dimulai dengan mengunduh dataset "World Happiness Report" yang  tersedia dari sumber yang terpercaya. Selanjutnya, memahami struktur dan format data yang ada pada setiap-setiap variabel dan membaca dokumentasi untuk pemahaman lebih lanjut mengenai definisi setiap variabel. Selanjutnya, mengidentifikasi dan menangani variabel yang memiliki data kosong jika ada dan mengidentifikasi variabel-variabel yang berkorelasi dengan tingkat kebahagiaan di setiap negara. Terakhir, membuat visualisasi data sepertu histogram, scatter plot untuk memahami hubungan antar variabel.

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# ##**Collect Initial Data**

# %% [markdown]
# Dataset "World Happiness Report" adalah sebuah dataset yang bersumber dari Kaggle yang memberikan informasi tentang tingkat kebahagiaan di berbagai negara di dunia. Dikutip dari Kaggle, skor dan peringkat setiap negara menggunakan data dari Gallup World Poll. Skor tersebut didasarkan pada jawaban atas pertanyaan utama evaluasi kehidupan yang ditanyakan dalam bentuk poll.
# Dataset ini telah diupload ke github dengan nama akun Lidia Aprilia pada repository yang bernama "Mini Project Data Mining 2024" dan direktori "Checkpoint (1) - Business Understanding" dengan format csv.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Lidiaaprilia/Mini-Project-Data-Mining-2024/main/Checkpoint%20(1)%20-%20Business%20Understanding/Dataset%20World%20Hapiness%20Report%202015.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# ##**Describe Data**

# %% [markdown]
# ####Informasi Dasar

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# Pada dataset "World Happiness Report" terdapat 158 baris dan 12 kolom. Hal ini menunjukkan bahwa dataset ini mencakup data dari 158 negara yang diamati tingkat kebahagiaannya. Setiap baris mewakili satu negara. Sementara setiap kolom memberikan informasi tentang berbagai variabel yang berkaitan dengan kebahagiaan di negara tersebut.

# %% [markdown]
# ####Informasi Lanjutan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# Berikut adalah penjelasan mengenai masing-masing dari 12 kolom dalam dataset "World Happiness Report":
# 1. Country
#
# Kolom ini berisi nama-nama negara diseluruh dunia yang diamati pada dataset ini. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data kolom ini berupa object, yaitu tipe data yang digunakan untuk nilai-nilai teks/string.
# 2. Region
#
# Kolom ini berisi wilayah geografis, seperti benua dari masing-masing negara. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data kolom ini berupa object, yaitu tipe data yang digunakan untuk nilai-nilai teks/string.
# 3. Happiness Rank
#
# Kolom ini berisi peringkat kebahagiaan suatu negara berdasarkan skor kebahagiaan. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data kolom ini berupa int64, yaitu tipe data untuk nilai numerik berupa bilangan bulat.
# 4. Happiness Score
#
# Kolom ini berisi skor kebahagiaan rata-rata suatu negara. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data pada kolom ini berupa float64, yaitu tipe data untuk nilai numerik berupa bilangan desimal.
# 5. Standard Error
#
# Kolom ini berisi nilai standar error, yaitu standar deviasi dari skor kebahagiaan pada kolom "Happiness Score". Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data pada kolom ini berupa float64, yaitu tipe data untuk nilai numerik berupa bilangan desimal.
# 6. Economy (GDP per Capita)
#
# Kolom ini berisi nilai untuk mengetahui seberapa besar kontribusi pendapatan per kapita setiap negara terhadap perhitungan skor kebahagiaan. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data pada kolom ini berupa float64, yaitu tipe data untuk nilai numerik berupa bilangan desimal.
# 7. Family
#
# Kolom ini berisi nilai untuk mengetahui seberapa besar poin kontribusi kesejahteraan keluarga setiap negara terhadap perhitungan skor kebahagiaan. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data pada kolom ini berupa float64, yaitu tipe data untuk nilai numerik berupa bilangan desimal.
# 8. Health (life expectancy)
#
# Kolom ini berisi nilai untuk mengetahui seberapa besar kontribusi poin harapan hidup setiap negara terhadap perhitungan skor kebahagiaan. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data pada kolom ini berupa float64, yaitu tipe data untuk nilai numerik berupa bilangan desimal.
# 9. Freedom
#
# Kolom ini berisi nilai untuk mengetahui seberapa besar kontribusi poin kebebasan dalam berpendapat, memilih pilihan hidup setiap negara terhadap perhitungan skor kebahagiaan. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data pada kolom ini berupa float64, yaitu tipe data untuk nilai numerik berupa bilangan desimal.
# 10. Trust (Government Corruption)
#
# Kolom ini berisi nilai untuk mengetahui seberapa besar kontribusi poin tingkat korupsi setiap negara terhadap perhitungan skor kebahagiaan. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data pada kolom ini berupa float64, yaitu tipe data untuk nilai numerik berupa bilangan desimal.
# 11. Generosity
#
# Kolom ini berisi nilai untuk mengetahui seberapa besar kontribusi poin kedermawanan setiap negara terhadap perhitungan skor kebahagiaan. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data pada kolom ini berupa float64, yaitu tipe data untuk nilai numerik berupa bilangan desimal.
# 12. Dystopia Residual
#
# Kolom ini berisi nilai untuk mengetahui seberapa besar kontribusi poin distopia residual setiap negara terhadap perhitungan skor kebahagiaan. Kolom ini memiliki 158 nilai non-null, yang berarti tidak ada data kosong dalam dataset. Adapun tipe data pada kolom ini berupa float64, yaitu tipe data untuk nilai numerik berupa bilangan desimal. Dikutip dari Kaggle, tujuan dalam menetapkan Distopia adalah untuk memiliki tolak ukur yang dapat dibandingkan dengan semua negara dalam hal masing-masing dari 6 variabel utama.

# %% [markdown]
# ####Informasi Statistika Deskriptif

# %%
df[['Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']].describe()
# Out:
#        Happiness Score  Economy (GDP per Capita)      Family  \
# count       158.000000                158.000000  158.000000
# mean          5.375734                  0.846137    0.991046
# std           1.145010                  0.403121    0.272369
# min           2.839000                  0.000000    0.000000
# 25%           4.526000                  0.545808    0.856823
# 50%           5.232500                  0.910245    1.029510
# 75%           6.243750                  1.158448    1.214405
# max           7.587000                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# ...

# %% [markdown]
# Output diatas merupakan informasi statistika deskriptif untuk setiap kolom numerik dalam dataset "World Happiness Report". Berikut adalah penjelasan untuk setiap kolom dari output diatas:
# 1. Kolom Happiness Score
#
# Kolom ini memiliki 158 data yang mencakup setiap negara yang diamati tingkat kebahagiaannya. Setiap data mewakili satu negara. Adapun rata-rata dari happiness score dari seluruh negara adalah 5.375734, standar deviasi/simpangan bakunya sebesar 1.145010, happiness score terendah yaitu 2.839000 dan tertinggi sebesar 7.587000 yang masing-masing merupakan skor dari negara yang berada pada peringkat terakhir dan pertama. Selanjutnya, ada kuartil pertama (Q1/25%) sebesar 4.526000 yang menunjukkan skor tengah antara skor terkecil dan median pada kolom ini. Dengan kata lain, negara yang memiliki skor dibawah Q1 merupakan negara dengan peringkat 25% terbawah pada kolom ini. Selain kuartil pertama, terdapat kuartil kedua (Q2/50%) atau median data sebesar 5.232500 yang menunjukkan skor tengah dari seluruh negara. Terakhir, ada kuartil ketiga (Q3/75%) sebesar 6.243750 yang menunjukkan skor tengah antara skor tertinggi dan median pada kolom ini. Dengan kata lain, negara yang memiliki skor diatas Q3 merupakan negara dengan peringkat 25% teratas pada Happiness Score.
#
#
# 2. Kolom Economy (GDP per Capita)
#
# Kolom ini memiliki 158 data yang mencakup setiap negara yang diamati tingkat kebahagiaannya. Setiap data mewakili satu negara. Adapun nilai rata-rata pada kolom ini adalah 0.846137, standar deviasi/simpangan bakunya sebesar 0.403121, nilai terendahnya yaitu 0.000000 dan tertinggi sebesar 1.690420. Selanjutnya, ada kuartil pertama (Q1/25%) sebesar 0.545808 yang menunjukkan nilai tengah antara nilai terkecil dan median pada kolom ini. Selain kuartil pertama, terdapat kuartil kedua (Q2/50%) atau median data sebesar 0.910245 yang menunjukkan nilai tengah dari seluruh negara. Terakhir, ada kuartil ketiga (Q3/75%) sebesar 1.158448 yang menunjukkan nilai tengah antara nilai tertinggi dan median pada kolom ini.
#
# 3. Family
#
# Kolom ini memiliki 158 data yang mencakup setiap negara yang diamati tingkat kebahagiaannya. Setiap data mewakili satu negara. Adapun nilai rata-rata pada kolom ini adalah 0.991046, standar deviasi/simpangan bakunya sebesar 0.272369, nilai terendahnya yaitu 0.000000 dan tertinggi sebesar 1.402230. Selanjutnya, ada kuartil pertama (Q1/25%) sebesar 0.856823 yang menunjukkan nilai tengah antara nilai terkecil dan median pada kolom ini. Selain kuartil pertama, terdapat kuartil kedua (Q2/50%) atau median data sebesar 1.029510 yang menunjukkan nilai tengah dari seluruh negara. Terakhir, ada kuartil ketiga (Q3/75%) sebesar 1.214405 yang menunjukkan nilai tengah antara nilai tertinggi dan median pada kolom ini.
#
# 4. Kolom Health (Life Expectancy)
#
#
# Kolom ini memiliki 158 data yang mencakup setiap negara yang diamati tingkat kebahagiaannya. Setiap data mewakili satu negara. Adapun nilai rata-rata pada kolom ini adalah 0.630529, standar deviasi/simpangan bakunya sebesar 0.247078, nilai terendahnya yaitu 0.000000 dan tertinggi sebesar 1.025250. Selanjutnya, ada kuartil pertama (Q1/25%) sebesar 0.439185 yang menunjukkan nilai tengah antara nilai terkecil dan median pada kolom ini. Selain kuartil pertama, terdapat kuartil kedua (Q2/50%) atau median data sebesar 0.696705 yang menunjukkan nilai tengah dari seluruh negara. Terakhir, ada kuartil ketiga (Q3/75%) sebesar 0.811013 yang menunjukkan nilai tengah antara nilai tertinggi dan median pada kolom ini.
#
# 5. Kolom Freedom
#
# Kolom ini memiliki 158 data yang mencakup setiap negara yang diamati tingkat kebahagiaannya. Setiap data mewakili satu negara. Adapun nilai rata-rata pada kolom ini adalah 0.428615, standar deviasi/simpangan bakunya sebesar 0.150693, nilai terendahnya yaitu 0.000000 dan tertinggi sebesar 0.669730. Selanjutnya, ada kuartil pertama (Q1/25%) sebesar 0.328330 yang menunjukkan nilai tengah antara nilai terkecil dan median pada kolom ini. Selain kuartil pertama, terdapat kuartil kedua (Q2/50%) atau median data sebesar 0.435515 yang menunjukkan nilai tengah dari seluruh negara. Terakhir, ada kuartil ketiga (Q3/75%) sebesar 0.549092 yang menunjukkan nilai tengah antara nilai tertinggi dan median pada kolom ini.
#
# 6. Kolom Trust (Government Corruption)
#
# Kolom ini memiliki 158 data yang mencakup setiap negara yang diamati tingkat kebahagiaannya. Setiap data mewakili satu negara. Adapun nilai rata-rata pada kolom ini adalah 0.143422, standar deviasi/simpangan bakunya sebesar 0.120034, nilai terendahnya yaitu 0.000000 dan tertinggi sebesar 0.551910. Selanjutnya, ada kuartil pertama (Q1/25%) sebesar 0.061675 yang menunjukkan nilai tengah antara nilai terkecil dan median pada kolom ini. Selain kuartil pertama, terdapat kuartil kedua (Q2/50%) atau median data sebesar 0.107220 yang menunjukkan nilai tengah dari seluruh negara. Terakhir, ada kuartil ketiga (Q3/75%) sebesar 0.180255 yang menunjukkan nilai tengah antara nilai tertinggi dan median pada kolom ini.
#
# 7. Kolom Generosity
#
# Kolom ini memiliki 158 data yang mencakup setiap negara yang diamati tingkat kebahagiaannya. Setiap data mewakili satu negara. Adapun nilai rata-rata pada kolom ini adalah 0.237296, standar deviasi/simpangan bakunya sebesar 0.126685, nilai terendahnya yaitu 0.000000 dan tertinggi sebesar 0.795880. Selanjutnya, ada kuartil pertama (Q1/25%) sebesar 0.150553 yang menunjukkan nilai tengah antara nilai terkecil dan median pada kolom ini. Selain kuartil pertama, terdapat kuartil kedua (Q2/50%) atau median data sebesar 0.216130 yang menunjukkan nilai tengah dari seluruh negara. Terakhir, ada kuartil ketiga (Q3/75%) sebesar 0.309883 yang menunjukkan nilai tengah antara nilai tertinggi dan median pada kolom ini.
#
# 8. Kolom Dystopia Residual
#
# Kolom ini memiliki 158 data yang mencakup setiap negara yang diamati tingkat kebahagiaannya. Setiap data mewakili satu negara. Adapun nilai rata-rata pada kolom ini adalah 2.098977, standar deviasi/simpangan bakunya sebesar 0.553550, nilai terendahnya yaitu 0.328580 dan tertinggi sebesar 3.602140. Selanjutnya, ada kuartil pertama (Q1/25%) sebesar 01.759410 yang menunjukkan nilai tengah antara nilai terkecil dan median pada kolom ini. Selain kuartil pertama, terdapat kuartil kedua (Q2/50%) atau median data sebesar 2.095415 yang menunjukkan nilai tengah dari seluruh negara. Terakhir, ada kuartil ketiga (Q3/75%) sebesar 2.462415 yang menunjukkan nilai tengah antara nilai tertinggi dan median pada kolom ini.

# %% [markdown]
# ##**Exploration Data Analysis**

# %%
data = dict(type = 'choropleth',
           locations = df['Country'],
           locationmode = 'country names',
           colorscale='agsunset',
           z = df['Happiness Score'],
           text = df['Country'],
           colorbar = {'title':'Happiness Score'})

layout = dict(title = 'World Happiness Score Across Countries',
              geo = dict(showframe = True, projection = {'type': 'natural earth'}))

choromap3 = go.Figure(data = [data], layout=layout)

iplot(choromap3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Visualisasi dataset World Happiness Report menggunakan peta dunia adalah salah satu cara efektif untuk menyajikan informasi tentang skor kebahagiaan di berbagai negara di seluruh dunia secara geografis.
#
# Setiap negara diwakili oleh wilayah/region yang ditandai dengan warna yang bervariasi sesuai dengan skala warna untuk memperjelas skor kebahagiaan di setiap negara. Negara dengan warna yang lebih terang menunjukkan skor kebahagiaan yang lebih tinggi. Sementara warna yang lebih gelap menunjukkan skor kebahagiaan yang lebih rendah.
#
# Sebagai contoh, skor kebahagiaan negara Canada sebesar 7.427. Oleh karena itu, wilayah negaranya berwarna cokelat terang. Berbeda dengan negara Syria yang berwarna ungu gelap bahkan mendekati warna biru tua karena memiliki skor kebahagiaan sebesar 3.006, jauh lebih rendah daripada negara Canada.
#
# Dapat kita simpulkan bahwa negara Canada berada pada peringkat teratas dan negara Syria berada pada peringkat terbawah untuk tingkat kebahagiaan negaranya.
#
# Melalui visualisasi ini diharapkan dapat membantu pengguna untuk mendapatkan wawasan terkait perbedaan kebahagiaan antar negara dan dapat digunakan sebagai dasar untuk analisis lebih lanjut tentang variabel yang memengaruhi kebahagiaan setiap negara.

# %%
region_lists = list(df['Region'].unique())
region_happiness_ratio = []

for each in region_lists:
    region = df[df['Region'] == each]
    region_happiness_rate = region['Happiness Score'].sum() / len(region)
    region_happiness_ratio.append(region_happiness_rate)

data = pd.DataFrame({'region': region_lists, 'region_happiness_ratio': region_happiness_ratio})

sorted_region = data.sort_values(by='region_happiness_ratio', ascending=False)

fig = px.bar(sorted_region, y='region', x='region_happiness_ratio',
             labels={'region_happiness_ratio': 'Region Happiness Ratio'}, width=800,
             title='World Happiness Ratio Across Regions', color='region_happiness_ratio',
             color_continuous_scale='agsunset', orientation='h')
fig.update_yaxes(title='Region', tickangle=-45)
fig.update_xaxes(title='Region Happiness Ratio')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Barplot diatas terdiri dari batang horizontal, dimana tinggi setiap batang menunjukkan rasio kebahagiaan untuk masing-masing wilayah. Setiap batang diberi label yang menunjukkan nama wilayahnya.
#
# Selain itu, setiap batang memiliki warna yang berbeda. Semakin terang warna batangnya, maka semakin tinggi rasio kebahagiaan wilayah tersebut. Sebaliknya, semakin gelap warna batangnya, maka semakin rendah rasio kebahagiaan wilayahnya.
#
# Sebagai contoh, wilayah Australia dan New Zealand memiliki rasio diatas 7, maka batangnya berwarna kuning terang. Berbeda dengan batang wilayah Sub-Saharan Africa yang berwarna ungu gelap karena memiliki rasio di range 4-5, jauh lebih rendah daripada wilayah Australia dan New Zealand.
#
# Dapat kita tarik kesimpulan bahwa warga yang tinggal di negara yang terletak pada wilayah Australia dan New Zealand jauh lebih bahagia daripada warga yang tinggal di negara yang terletak pada wilayah Sub-Saharan Africa.
#
# Melalui visualisasi dataset World Happiness Report menggunakan barplot diharapkan dapat memberikan gambaran terkait rasio kebahagiaan di berbagai wilayah/region di seluruh dunia karena barplot memperlihatkan perbandingan langsung rasio kebahagiaan di berbagai wilayah.

# %%
selected_columns = ['Happiness Score', 'Economy (GDP per Capita)',
                    'Family', 'Health (Life Expectancy)', 'Freedom',
                    'Trust (Government Corruption)', 'Generosity']

df_selected = df[selected_columns]

fig = px.imshow(df_selected.corr(), color_continuous_scale='agsunset')
fig.update_layout(title="Correlation Heatmap of World Happiness Report Variables")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Setiap sel dalam heatmap mewakili korelasi antara dua variabel dalam dataset ini. Warna setiap sel menunjukkan tingkat korelasi dan arah korelasi antar variabel. Semakin terang warna selnya, maka semakin tinggi tingkat korelasinya. Sebaliknya, semakin gelap warna selnya, maka semakin rendah tingkat korelasinya.
#
# Sebagai contoh, variabel Happiness Score dan variabel Economy (GDP per Capita) memiliki tingkat korelasi sebesar 0.7809655 dengan warna sel orange terang Artinya nilai dari kedua variabel ini sangat berpengaruh satu sama lain. Berbeda dengan variabel Happiness Score dan variabel Generosity yang memiliki tingkat korelasi sebesar 0.1803185 dengan warna sel ungu. Artinya nilai dari kedua variabel tidak cukup berpengaruh satu sama lain.
#
# Melalui visualisasi dataset World Happiness Report menggunakan heatmap diharapkan dapat membantu dalam memahami korelasi antar variabel yang memengaruhi skor kebahagiaan setiap negara di seluruh dunia.

# %%
region_lists = list(df['Region'].unique())
share_economy = []
share_family = []
share_health = []
share_freedom = []
share_trust = []
share_generosity = []

for region in region_lists:
    region_data = df[df['Region'] == region]
    share_economy.append(region_data['Economy (GDP per Capita)'].mean())
    share_family.append(region_data['Family'].mean())
    share_health.append(region_data['Health (Life Expectancy)'].mean())
    share_freedom.append(region_data['Freedom'].mean())
    share_trust.append(region_data['Trust (Government Corruption)'].mean())
    share_generosity.append(region_data['Generosity'].mean())

df_bar = pd.DataFrame({
    'Region': region_lists,
    'Economy': share_economy,
    'Family': share_family,
    'Health': share_health,
    'Freedom': share_freedom,
    'Trust': share_trust,
    'Generosity': share_generosity
})

fig = px.bar(df_bar, y='Region', x=['Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity'],
             barmode='stack',
             orientation='h',
             title='Factors Affecting Happiness Score Across Regions',
             labels={'value': 'Percentage of Region', 'variable': 'Factors'},
             color_discrete_sequence=px.colors.qualitative.Plotly)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Dalam stacked barplot, setiap batang mewakili satu region/wilayah, sedangkan bagian-bagian dari setiap batang mewakili besaran nilai dari variabel-variabel yang ada pada dataset World Happiness Report, seperti economy, family, health, freedom, trust, dan generosity. Bagian yang lebih tinggi menunjukkan bahwa variabel tersebut berpengaruh besar terhadap tingkat kebahagiaan suatu wilayah/region. Selain itu, setiap variabel diwakili oleh warna yang berbeda.
#
# Sebagai contoh, pada wilayah Southern Asia, variabel yang berpengaruh besar terhadap tingkat kebahagiaan wilayah ini adalah variabel Family, dan variabel yang berpengaruh kecil yaitu Trust.
#
# Dapat kita tarik kesimpulan bahwa faktor dukungan sosial dari keluarga, kerabat, dll merupakan poin terpenting dalam meningkatkan kebahagiaan para warga yang tinggal di negara yang terletak pada wilayah Southern Asia.
#
# Melalui visualisasi stacked barplot, diharapkan dapat memudahkan pengguna untuk memahami dan membandingkan besaran nilai masing-masing variabel terhadap kebahagiaan suatu wilayah/region.

# %% [markdown]
# ##**Verify Data Quality**

# %% [markdown]
# ####Missing Values

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                                Null Ratio %
# Country                                 0.0
# Region                                  0.0
# Happiness Rank                          0.0
# Happiness Score                         0.0
# Standard Error                          0.0
# Economy (GDP per Capita)                0.0
# Family                                  0.0
# Health (Life Expectancy)                0.0
# Freedom                                 0.0
# Trust (Government Corruption)           0.0
# Generosity                              0.0
# Dystopia Residual                       0.0

# %% [markdown]
# Melalui output diatas, dapat kita ketahui bahwa dataset World Happiness Report tidak memiliki data kosong. Artinya setiap baris/entri memiliki nilai untuk setiap kolom dan variabel yang diukur, tidak ada nilai yang hilang/kosong dalam dataset ini.

# %% [markdown]
# ####Outliers Values

# %%
df_without_rank = df.drop(columns=['Happiness Rank'])

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_without_rank)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %% [markdown]
# Melalui output diatas, dapat kita ketahui bahwa dataset World Happiness Report memiliki outliers, yaitu adanya data yang tidak biasa dengan tren umum dalam setiap variabel yang ditandai dengan adanya bulatan diluar garis boxplot. Outliers tersebut berada pada kolom standard error, family, trust, generosity, dan dystopia residual.
#
# Adanya outliers dalam dataset ini menunjukkan adanya variasi nilai yang signifikan dalam data yang dapat memengaruhi hasil analisis dan permodelan kedepannya.

# %% [markdown]
# ####Duplicated Values

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Length: 158, dtype: bool

# %% [markdown]
# Melalui output diatas, dapat kita ketahui bahwa dataset World Happiness Report tidak memiliki data duplikat pada setiap barisnya. Hal ini menunjukkan bahwa setiap baris dalam dataset ini memiliki informasi unik yang berbeda dengan baris lainnya.

# %% [markdown]
# #**DATA PREPARATION**

# %% [markdown]
# ##**Data Cleaning**

# %% [markdown]
# ####**Penanganan Missing Values**

# %% [markdown]
# ######**Pengecekkan Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                                Null Ratio %
# Country                                 0.0
# Region                                  0.0
# Happiness Rank                          0.0
# Happiness Score                         0.0
# Standard Error                          0.0
# Economy (GDP per Capita)                0.0
# Family                                  0.0
# Health (Life Expectancy)                0.0
# Freedom                                 0.0
# Trust (Government Corruption)           0.0
# Generosity                              0.0
# Dystopia Residual                       0.0

# %% [markdown]
# Melalui output diatas, dapat kita ketahui bahwa dataset World Happiness Report tidak memiliki data kosong. Artinya setiap baris/entri memiliki nilai untuk setiap kolom dan variabel yang diukur, tidak ada nilai yang hilang/kosong dalam dataset ini. Sehingga, kita tidak perlu melakukan penanganan dataset berupa penghapusan kolom missing value atau imputasi missing value.

# %% [markdown]
# ####**Penanganan Duplicated Values**

# %% [markdown]
# ######**Pengecekkan Nilai Duplikat**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %% [markdown]
# Melalui output diatas, dapat kita ketahui bahwa dataset World Happiness Report tidak memiliki data duplikat pada setiap barisnya. Hal ini menunjukkan bahwa setiap baris dalam dataset ini memiliki informasi unik yang berbeda dengan baris lainnya. Sehingga, kita tidak perlu melakukan penanganan dataset berupa penghapusan kolom duplikat.

# %% [markdown]
# ####**Penanganan Outliers**

# %% [markdown]
# ######**Pengecekkan Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom                          Persentase Outliers
# Happiness Rank                            0.000000
# Happiness Score                           0.000000
# Standard Error                            6.329114
# Economy (GDP per Capita)                  0.000000
# Family                                    1.898734
# Health (Life Expectancy)                  0.000000
# Freedom                                   0.000000
# Trust (Government Corruption)             8.860759
# Generosity                                1.265823
# Dystopia Residual                         3.164557

# %%
df_without_rank = df.drop(columns=['Happiness Rank'])

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_without_rank)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %% [markdown]
# Melalui output diatas, dapat kita ketahui bahwa dataset World Happiness Report memiliki outliers, yaitu adanya data yang tidak biasa dengan tren umum dalam setiap variabel yang ditandai dengan adanya bulatan diluar garis boxplot. Outliers tersebut berada pada kolom standard error, family, trust, generosity, dan dystopia residual. Masing-masing kolom memiliki persentase outliers dibawah 10% yang berarti kolom-kolom tersebut harus dilakukan penanganan dataset seperti penghapusan outliers atau imputasi outliers. Tetapi karena outliers tidak berada jauh dari batas atas (nilai maksimum) dan batas bawah (nilai minimum) boxplot, maka tidak perlu dilakukan penanganan, meskipun persentase outliersnya dibawah 10%.

# %% [markdown]
# ##**Construct Data**

# %% [markdown]
# ####**Melakukan Rekayasa Fitur (Feature Engineering)**

# %%
def categorize_score(score):
    if 2.00 <= score < 4.00:
        return 'Low'
    elif 4.00 <= score < 6.00:
        return 'Middle'
    elif 6.00 <= score <= 8.00:
        return 'High'
    else:
        return 'Not Valid Score'

df['Happiness Score Category'] = df['Happiness Score'].apply(categorize_score)

# %% [markdown]
# #####**Pengecekkan Hasil**

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Melalui output diatas, terdapat tambahan kolom yaitu "Happiness Score Category". Penambahan kolom diatas bertujuan untuk memudahkan pengguna dalam melihat pengkategorian score kebahagiaan negara agar dataset semakin mudah untuk dipahami. Untuk negara yang memiliki rentang score 2.00 hingga 4.00 dikategorikan "Low" yang berarti negara tersebut memiliki tingkat kebahagiaan yang rendah, score 4.00 hingga 6.00 dikategorikan "Middle" yang berarti negara tersebut memiliki tingkat kebahagiaan yang sedang, dan score 6.00 hingga 8.00 dikategorikan "High" yang berarti negara tersebut memiliki tingkat kebahagiaan yang tinggi. Contohnya, negara Switzerland berada pada kategori "High" karena score kebahagiaannya adalah 7.587. Sedangkan, negara Togo berada pada kategori "Low" karena score kebahagiaannya adalah 2.839.

# %% [markdown]
# ##**Data Reduction**

# %% [markdown]
# ####**Mengurangi Fitur - Fitur Yang Kurang Relevan**

# %%
df = df.drop(['Standard Error','Dystopia Residual'],axis=1)

# %% [markdown]
# #####**Pengecekkan Hasil**

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity Happiness Score Category
# 0                        0.41978     0.29678                     High
# ...

# %% [markdown]
# Melalui output diatas, terdapat pengurangan/penghapusan kolom, yaitu kolom Standard Error dan Dystopia Residual. Hal ini dilakukan karena kedua kolom tersebut kurang relevan dalam menilai tingkat kebahagiaan negara. Umumnya, faktor yang menjadi fokus analisis tingkat kebahagiaan negara yaitu faktor seperti ekonomi, keluarga/dukungan sosial, kesehatan, kebebasan, kepercayaan terhadap pemerintah, dan kedermawanan.

# %% [markdown]
# ##**Data Transformation**

# %% [markdown]
# ####**Mapping**

# %%
df['Happiness Score Category'] = df['Happiness Score Category'].map({'Low': 1, 'Middle': 2,'High': 3}).astype(int)

# %% [markdown]
# #####**Pengecekkan Hasil**

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %% [markdown]
# Melalui output diatas, terdapat perubahan data pada kolom "Happiness Score Category". Perubahan data yang dimaksud yaitu perubahan data kategorikal menjadi nilai numerik. Dimana awalnya kategori pada kolom tersebut yaitu "Low", "Middle", dan "High". Namun setelah dilakukan mapping, maka nilai dalam kolom tersebut berubah menjadi numerik yang merepresentasikan kategori awal. Untuk "Low" diubah menjadi angka "1", "Middle" diubah menjadi angka "2", dan "High" diubah menjadi angka "3". Hal ini dilakukan agar model algoritma lebih optimal bekerja ketika menerima input data berupa angka dengan skala yang seragam.

# %% [markdown]
# ####**Encoding**

# %%
country = df['Country'] #Menyimpan kolom "Country" dalam variabel sementara, agar setelah selesai melakukan analisa selanjutnya, kolom ini dapat digabung kembali dengan dataframe
df_new = df.drop(columns=['Country'])

region_encoded = pd.get_dummies(df_new['Region'], prefix='Region')
df_encoded = pd.concat([df_new, region_encoded], axis=1)
df_encoded.drop(columns=['Region'], inplace=True)

# %% [markdown]
# #####**Pengecekkan Hasil**

# %%
df_encoded #Membuat variabel baru yang tidak ada kolom "Country"nya
# Out:
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)   Family  \
# 0                 1            7.587                   1.39651  1.34951
# 1                 2            7.561                   1.30232  1.40223
# 2                 3            7.527                   1.32548  1.36058
# 3                 4            7.522                   1.45900  1.33095
# 4                 5            7.427                   1.32629  1.32261
# ..              ...              ...                       ...      ...
# 153             154            3.465                   0.22208  0.77370
# 154             155            3.340                   0.28665  0.35386
# 155             156            3.006                   0.66320  0.47489
# 156             157            2.905                   0.01530  0.41587
# 157             158            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# Output diatas merupakan hasil dari encoding pada kolom "Region", dimana kolom "Region" mengonversi setiap nama region/wilayah menjadi angka biner yang menunjukkan keberadaan atau ketiadaan nama region tersebut. Nilai 1 menunjukkan keberadaan nama region tersebut, sedangkan 0 menunjukkan ketiadaanya. Hal ini dilakukan agar model algoritma lebih optimal bekerja ketika menerima input data berupa angka dengan skala yang seragam.
#
#
# Sebagai catatan, karena analisa lebih optimal bekerja dengan data berupa angka, maka kolom "Country" kita hapus dan simpan di variabel sementara. Sehingga setelah melakukan analisa, kolom ini dapat digabung kembali dengan dataframe. Karena jika dilakukan encoding pada kolom ini, akan menghasilkan sangat banyak kolom tambahan, yaitu 158 kolom, mengingat jumlah negara pada dataset ini sebanyak 158 negara.

# %%
df2 = pd.concat([df_encoded, country], axis=1) #Gabungkan kembali kolom "Country" setelah analisa pada tahap encoding selesai
df2
# Out:
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)   Family  \
# 0                 1            7.587                   1.39651  1.34951
# 1                 2            7.561                   1.30232  1.40223
# 2                 3            7.527                   1.32548  1.36058
# 3                 4            7.522                   1.45900  1.33095
# 4                 5            7.427                   1.32629  1.32261
# ..              ...              ...                       ...      ...
# 153             154            3.465                   0.22208  0.77370
# 154             155            3.340                   0.28665  0.35386
# 155             156            3.006                   0.66320  0.47489
# 156             157            2.905                   0.01530  0.41587
# 157             158            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# #**Export To CSV**

# %%
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
df2.to_csv('Data Cleaned.csv', index=False)
